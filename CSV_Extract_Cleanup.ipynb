# %%
import pandas as pd

# %%
# read csv into pandas
NCHS = pd.read_csv('NCHS_-_Leading_Causes_of_Death__United_States.csv')

# %%
NCHS.head()
# Out:
#    Year                                     113 Cause Name      Cause Name  \
# 0  2012  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 1  2016  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 2  2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 3  2000  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 4  2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
#
#                   State  Deaths  Age-adjusted Death Rate
# 0               Vermont      21                      2.6
# 1               Vermont      30                      3.7
# 2               Vermont      30                      3.8
# 3  District of Columbia      23                      3.8
# 4               Arizona     325                      4.1

# %%
state_code = pd.read_csv('state_code.csv')

# %%
state_code.head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
NCHS.describe()
# Out:
#                Year        Deaths  Age-adjusted Death Rate
# count  10296.000000  1.029600e+04             10296.000000
# mean    2007.500000  1.536793e+04               128.037383
# std        5.188379  1.121457e+05               224.381865
# min     1999.000000  2.100000e+01                 2.600000
# 25%     2003.000000  6.060000e+02                19.200000
# 50%     2007.500000  1.704500e+03                35.800000
# 75%     2012.000000  5.678000e+03               153.025000
# max     2016.000000  2.744248e+06              1087.300000

# %%
NCHS.head(20)
# Out:
#     Year                                     113 Cause Name      Cause Name  \
# 0   2012  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 1   2016  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 2   2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 3   2000  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 4   2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 5   2009  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 6   2011  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 7   2015  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 8   2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 9   2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 10  2015  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# ...

# %%
#sort values 
NCHS = NCHS.sort_values('State').sort_values('Year')

# %%
# drop columns we don't need

NCHS = NCHS.drop(columns=['113 Cause Name','Age-adjusted Death Rate'])

# %%
NCHS.head()
# Out:
#        Year               Cause Name         State  Deaths
# 10114  1999               All causes  Pennsylvania  130283
# 4187   1999                 Diabetes       Indiana    1591
# 9320   1999            Heart disease      Arkansas    8315
# 3831   1999  Influenza and pneumonia     Wisconsin    1425
# 6499   1999   Unintentional injuries      Arkansas    1287

# %%
# find max year
NCHS.Year.max()
# Out:
# 2016

# %%
# drop years before 2013, since income data does not have data before then
NCHS = NCHS.loc[NCHS.Year>2012,:]

# %%
# check for years in new dataframe
NCHS.Year.unique()
# Out:
# array([2013, 2014, 2015, 2016], dtype=int64)

# %%
# look at unique values of "Cause Name column"
NCHS['Cause Name'].unique()
# Out:
# array(['CLRD', 'Cancer', 'Stroke', 'All causes', "Alzheimer's disease",
#        'Kidney disease', 'Unintentional injuries', 'Suicide',
#        'Influenza and pneumonia', 'Heart disease', 'Diabetes'],
#       dtype=object)

# %%
NCHS.Year.describe()
# Out:
# count    2288.000000
# mean     2014.500000
# std         1.118278
# min      2013.000000
# 25%      2013.750000
# 50%      2014.500000
# 75%      2015.250000
# max      2016.000000
# Name: Year, dtype: float64

# %%
#Year is a float, change to string
NCHS.Year = NCHS.astype({'Year': 'object'})

# %%
NCHS.head()
# Out:
#       Year           Cause Name          State  Deaths
# 5880  2013                 CLRD  New Hampshire     668
# 7748  2013               Cancer   South Dakota    1577
# 5192  2013               Stroke  United States  128978
# 9529  2013           All causes       Nebraska   15754
# 4113  2013  Alzheimer's disease       Michigan    3220

# %%
# rearrange columns

NCHS = NCHS[['State','Year','Cause Name','Deaths']]

# %%
# reset index
NCHS.reset_index(inplace=True)

# %%
# drop old index
NCHS = NCHS[['State','Year','Cause Name','Deaths']]

# %%
NCHS.head()
# Out:
#            State  Year           Cause Name  Deaths
# 0  New Hampshire  2013                 CLRD     668
# 1   South Dakota  2013               Cancer    1577
# 2  United States  2013               Stroke  128978
# 3       Nebraska  2013           All causes   15754
# 4       Michigan  2013  Alzheimer's disease    3220

# %%
#output to a csv
NCHS.to_csv('NCHS.csv',index=False, header=True)
